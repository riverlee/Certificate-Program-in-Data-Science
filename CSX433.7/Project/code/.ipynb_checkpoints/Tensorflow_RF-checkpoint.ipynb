# %% [markdown]
# ## Tensorflow Random Forest
#
# - Data are stored in **pickle** by **prepare_data** sript

# %%
import pickle

from __future__ import print_function

import numpy as np

import tensorflow as tf
from tensorflow.contrib.tensor_forest.python import tensor_forest
from tensorflow.python.ops import resources

# Ignore all GPUs, tf random forest does not benefit from it.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
## load data
with open('../data/features.pickle', 'rb') as handle:
    d = pickle.load(handle)
d.keys()
# Out:
# ['test', 'train']

# %%
d['train'].keys() ## feature is a matrix, label is a list
# Out:
# ['features', 'label_original', 'label']

# %%
d['train']['label'][:4]
# Out:
# [0, 0, 0, 2]

# %%
type(d['train']['label'][1])
# Out:
# int

# %%
train_size = d['train']['features'].shape[0]
# Parameters
num_steps = 500 # Total steps to train
batch_size = 1024 # The number of samples per batch
num_classes = 3 # The 3 cluster
num_features = d['train']['features'].shape[1] # 188 feature
num_trees = 10
max_nodes = 1000

# Input and Target data
X = tf.placeholder(tf.float32, shape=[None, num_features])
# For random forest, labels must be integers (the class id)
Y = tf.placeholder(tf.int32, shape=[None])

# Random Forest Parameters
hparams = tensor_forest.ForestHParams(num_classes=num_classes,
                                      num_features=num_features,
                                      num_trees=num_trees,
                                      max_nodes=max_nodes).fill()

# Build the Random Forest
forest_graph = tensor_forest.RandomForestGraphs(hparams)
# Get training graph and loss
train_op = forest_graph.training_graph(X, Y)
loss_op = forest_graph.training_loss(X, Y)

# Measure the accuracy
infer_op, _, _ = forest_graph.inference_graph(X)
correct_prediction = tf.equal(tf.argmax(infer_op, 1), tf.cast(Y, tf.int64))
accuracy_op = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# Initialize the variables (i.e. assign their default value) and forest resources
init_vars = tf.group(tf.global_variables_initializer(),
    resources.initialize_resources(resources.shared_resources()))

# Start TensorFlow session
sess = tf.Session()

# Run the initializer
sess.run(init_vars)
# Out:
# INFO:tensorflow:Constructing forest with params =
# INFO:tensorflow:{'valid_leaf_threshold': 1, 'split_after_samples': 250, 'num_output_columns': 4, 'feature_bagging_fraction': 1.0, 'split_initializations_per_input': 1, 'bagged_features': None, 'min_split_samples': 5, 'max_nodes': 1000, 'num_features': 188, 'num_trees': 10, 'num_splits_to_consider': 188, 'base_random_seed': 0, 'num_outputs': 1, 'dominate_fraction': 0.99, 'max_fertile_nodes': 500, 'bagged_num_features': 188, 'dominate_method': 'bootstrap', 'bagging_fraction': 1.0, 'regression': False, 'num_classes': 3}
# INFO:tensorflow:training graph for tree: 0
# INFO:tensorflow:training graph for tree: 1
# INFO:tensorflow:training graph for tree: 2
# INFO:tensorflow:training graph for tree: 3
# INFO:tensorflow:training graph for tree: 4
# INFO:tensorflow:training graph for tree: 5
# INFO:tensorflow:training graph for tree: 6
# INFO:tensorflow:training graph for tree: 7
# INFO:tensorflow:training graph for tree: 8
# ...

# %%
# Training
for i in range(1, num_steps + 1):
    # Prepare Data
    # Get the next batch of MNIST data (only images are needed, not labels)
    idx = np.random.randint(0,train_size,batch_size)
    batch_x, batch_y = d['train']['features'][idx],np.array(d['train']['label'],dtype=np.int)[idx]
    _, l = sess.run([train_op, loss_op], feed_dict={X: batch_x, Y: batch_y})
    if i % 50 == 0 or i == 1:
        acc = sess.run(accuracy_op, feed_dict={X: batch_x, Y: batch_y})
        print('Step %i, Loss: %f, Acc: %f' % (i, l, acc))

# Test Model/on Trainning
test_x, test_y = d['train']['features'],d['train']['label']
print("Test Accuracy:", sess.run(accuracy_op, feed_dict={X: test_x, Y: test_y}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-48fa052d85c9> in <module>()
#       5     idx = np.random.randint(0,train_size,batch_size)
#       6     batch_x, batch_y = d['train']['features'][idx],np.array(d['train']['label'],dtype=np.int)[idx]
# ----> 7     _, l = sess.run([train_op, loss_op], feed_dict={X: batch_x, Y: batch_y})
#       8     if i % 50 == 0 or i == 1:
#       9         acc = sess.run(accuracy_op, feed_dict={X: batch_x, Y: batch_y})
#
# NameError: name 'sess' is not defined

# %%
## On test dataset output result and score it through datadriven.org
test_x,test_id= d['test']['features'],d['test']['id']
predict_y =

# %%
test_id
# Out:
#           id
# 0      50785
# 1      51630
# 2      17168
# 3      45559
# 4      49871
# 5      52449
# 6      24806
# 7      28965
# 8      36301
# 9      54122
# 10       419
# 11     45750
# 12       653
# 13     14017
# 14     44607
# 15     40228
# 16     27714
# 17     28785
# 18     28330
# 19     18532
# 20     69961
# 21     55083
# 22      8691
# 23     30331
# 24     70970
# 25     61136
# 26     28799
# 27     46825
# 28     44718
# 29     37350
# ...      ...
# 14820  52228
# 14821  70038
# 14822  25901
# 14823  21131
# 14824  26580
# 14825  66059
# 14826  32944
# 14827  13686
# 14828   8471
# 14829  19620
# 14830  74162
# 14831  37994
# 14832  71151
# 14833  45017
# 14834  12592
# 14835  58693
# 14836  57539
# 14837  71252
# 14838   7869
# 14839  57316
# 14840  59757
# 14841  64579
# 14842  57731
# 14843  65541
# 14844  68174
# 14845  39307
# 14846  18990
# 14847  28749
# 14848  33492
# 14849  68707
#
# [14850 rows x 1 columns]
